# %%
from src.extras.distances import get_distances
from sklearn import datasets
import seaborn as sns

# %%
iris = datasets.load_iris()["data"]
ds = get_distances(iris, "p", [1,2,3])
sns.heatmap(ds[1])
# Out:
# <Axes: >
